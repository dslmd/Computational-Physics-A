# %% [markdown]
# ## 一维情况

# %%
##最小二乘法
import numpy as np   ##科学计算库 
import scipy as sp   ##在numpy基础上实现的部分算法库
import matplotlib.pyplot as plt  ##绘图库
from scipy.optimize import leastsq  ##引入最小二乘法算法


f = open('1d_RW_return.txt')    #用test.txt先试试
s = f.read()
p = list(float(i) for i in s.split())

Xi=np.array(p[2::2])
Yi=np.array(p[3::2])

def func(p,x):
    A,v=p
    return A*x**(-v)

def error(p,x,y):
    return func(p,x)-y

p0=[0.7444741607084294,0.4912532742356371]

Para=leastsq(error,p0,args=(Xi,Yi))

A,v=Para[0]
print("求解的拟合为:")
print("y="+str(A)+"*N^(-"+str(v)+")")
print(Para[1])


#画样本点
plt.figure(figsize=(8,6)) ##指定图像比例： 8：6
plt.scatter(Xi,Yi,color="green",label="Sample",linewidth=2) 

#画拟合直线
x=np.linspace(0,5000,100) ##在0-15直接画100个连续点
y=A*x**(-v)
print(error)
plt.plot(x,y,color="red",label="fit",linewidth=2) 
plt.legend(loc='best') #绘制图例
plt.xlabel("N")
plt.ylabel("$P_d(N)$")
plt.title("1-d distribution $P_d(N)$")
plt.show();
# Out:
# 求解的拟合为:
# y=0.804503529134648*N^(-0.5015773238290624)
# 1
# <function error at 0x7fd10d2e71f0>
# <ipython-input-74-596619a332e9>:38: RuntimeWarning: divide by zero encountered in power
#   y=A*x**(-v)

# %%
##最小二乘法
import numpy as np   ##科学计算库 
import scipy as sp   ##在numpy基础上实现的部分算法库
import matplotlib.pyplot as plt  ##绘图库
from scipy.optimize import leastsq  ##引入最小二乘法算法


f = open('1d_RW_return.txt')    #用test.txt先试试
s = f.read()
p = list(float(i) for i in s.split())

Xi=np.array(p[2::2])
Xi=np.log(Xi)
Yi=np.array(p[3::2])
Yi=np.log(Yi)

def func(p,x):
    k,b=p
    return k*x+b

def error(p,x,y):
    return func(p,x)-y

p0=[-1.5,-0.46]

Para=leastsq(error,p0,args=(Xi,Yi))

k,b=Para[0]
#print("求解的拟合为:")
#print("y="+str(A)+"*N^(-"+str(v)+")")



#画样本点
plt.figure(figsize=(8,6)) ##指定图像比例： 8：6
plt.scatter(Xi,Yi,color="green",label="Sample",linewidth=2) 

#画拟合直线
x=np.linspace(3,9,100) ##在0-15直接画100个连续点
y=k*x+b
plt.plot(x,y,color="red",label="fit",linewidth=2) 
plt.legend(loc='best') #绘制图例
plt.xlabel("ln(N)")
plt.ylabel("$ln(P_d(N))$")
plt.title("1-d distribution $ln(P_d(N))$")
plt.show();

# %% [markdown]
# ## 二维情况

# %%
##最小二乘法
import numpy as np   ##科学计算库 
import scipy as sp   ##在numpy基础上实现的部分算法库
import matplotlib.pyplot as plt  ##绘图库
from scipy.optimize import leastsq  ##引入最小二乘法算法


f = open('2d_RW_return.txt')    #用test.txt先试试
s = f.read()
p = list(float(i) for i in s.split())

Xi=np.array(p[2::2])
Yi=np.array(p[3::2])

def func(p,x):
    A,v=p
    return A*x**(-v)

def error(p,x,y):
    return func(p,x)-y

p0=[0.7444741607084294,0.4912532742356371]

Para=leastsq(error,p0,args=(Xi,Yi))

A,v=Para[0]
print("求解的拟合为:")
print("y="+str(A)+"*N^(-"+str(v)+")")



#画样本点
plt.figure(figsize=(8,6)) ##指定图像比例： 8：6
plt.scatter(Xi,Yi,color="green",label="Sample",linewidth=2) 

#画拟合直线
x=np.linspace(0,5000,100) ##在0-15直接画100个连续点
y=A*x**(-v)
plt.plot(x,y,color="red",label="fit",linewidth=2) 
plt.legend(loc='best') #绘制图例
plt.xlabel("N")
plt.ylabel("$P_d(N)$")
plt.title("2-d distribution $P_d(N)$")
plt.show();
# Out:
# 求解的拟合为:
# y=0.6002880767985694*N^(-0.9922560376927576)
# <ipython-input-72-51cfa80bdd9a>:38: RuntimeWarning: divide by zero encountered in power
#   y=A*x**(-v)

# %%
##最小二乘法
import numpy as np   ##科学计算库 
import scipy as sp   ##在numpy基础上实现的部分算法库
import matplotlib.pyplot as plt  ##绘图库
from scipy.optimize import leastsq  ##引入最小二乘法算法


f = open('2d_RW_return.txt')    #用test.txt先试试
s = f.read()
p = list(float(i) for i in s.split())

Xi=np.array(p[2::2])
Xi=np.log(Xi)
Yi=np.array(p[3::2])
Yi=np.log(Yi)

def func(p,x):
    k,b=p
    return k*x+b

def error(p,x,y):
    return func(p,x)-y

p0=[-1.5,-0.46]

Para=leastsq(error,p0,args=(Xi,Yi))

k,b=Para[0]
#print("求解的拟合为:")
#print("y="+str(A)+"*N^(-"+str(v)+")")



#画样本点
plt.figure(figsize=(8,6)) ##指定图像比例： 8：6
plt.scatter(Xi,Yi,color="green",label="Sample",linewidth=2) 

#画拟合直线
x=np.linspace(3,8,100) ##在0-15直接画100个连续点
y=k*x+b
plt.plot(x,y,color="red",label="fit",linewidth=2) 
plt.legend(loc='best') #绘制图例
plt.xlabel("ln(N)")
plt.ylabel("$ln(P_d(N))$")
plt.title("2-d distribution $ln(P_d(N))$")
plt.show();

# %% [markdown]
# ## 三维情况

# %%
##最小二乘法
import numpy as np   ##科学计算库 
import scipy as sp   ##在numpy基础上实现的部分算法库
import matplotlib.pyplot as plt  ##绘图库
from scipy.optimize import leastsq  ##引入最小二乘法算法


f = open('3d_RW_return.txt')    #用test.txt先试试
s = f.read()
p = list(float(i) for i in s.split())

Xi=np.array(p[2::2])
Yi=np.array(p[3::2])

def func(p,x):
    A,v=p
    return A*x**(-v)

def error(p,x,y):
    return func(p,x)-y

p0=[0.01,1.5]

Para=leastsq(error,p0,args=(Xi,Yi))

A,v=Para[0]
print("求解的拟合为:")
print("y="+str(A)+"*N^(-"+str(v)+")")



#画样本点
plt.figure(figsize=(8,6)) ##指定图像比例： 8：6
plt.scatter(Xi,Yi,color="green",label="Sample",linewidth=2) 

#画拟合直线
x=np.linspace(0,5000,100) ##在0-15直接画100个连续点
y=A*x**(-v)
plt.plot(x,y,color="red",label="fit",linewidth=2) 
plt.legend(loc='best') #绘制图例
plt.xlabel("N")
plt.ylabel("$P_d(N)$")
plt.title("3-d distribution $P_d(N)$")
plt.show();
# Out:
# 求解的拟合为:
# y=0.630590448314045*N^(-1.5105864911004834)
# <ipython-input-69-da89d246d2b8>:38: RuntimeWarning: divide by zero encountered in power
#   y=A*x**(-v)

# %%
##最小二乘法
import numpy as np   ##科学计算库 
import scipy as sp   ##在numpy基础上实现的部分算法库
import matplotlib.pyplot as plt  ##绘图库
from scipy.optimize import leastsq  ##引入最小二乘法算法


f = open('3d_RW_return.txt')    #用test.txt先试试
s = f.read()
p = list(float(i) for i in s.split())

Xi=np.array(p[2::2])
Xi=np.log(Xi)
Yi=np.array(p[3::2])
Yi=np.log(Yi)

def func(p,x):
    k,b=p
    return k*x+b

def error(p,x,y):
    return func(p,x)-y

p0=[-1.5,-0.46]

Para=leastsq(error,p0,args=(Xi,Yi))

k,b=Para[0]
#print("求解的拟合为:")
#print("y="+str(A)+"*N^(-"+str(v)+")")



#画样本点
plt.figure(figsize=(8,6)) ##指定图像比例： 8：6
plt.scatter(Xi,Yi,color="green",label="Sample",linewidth=2) 

#画拟合直线
x=np.linspace(3,8,100) ##在0-15直接画100个连续点
y=k*x+b
plt.plot(x,y,color="red",label="fit",linewidth=2) 
plt.legend(loc='best') #绘制图例
plt.xlabel("ln(N)")
plt.ylabel("$ln(P_d(N))$")
plt.title("3-d distribution $ln(P_d(N))$")
plt.show();
# Out:
# <ipython-input-82-1b606b5cd81c>:15: RuntimeWarning: divide by zero encountered in log
#   Yi=np.log(Yi)
